# %% [markdown]
# <a href="https://colab.research.google.com/github/Anudeep003/Week1/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy matplotlib seaborn --quiet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8c8d3eff-0d42-4d82-ac64-c9a02952fe42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c8d3eff-0d42-4d82-ac64-c9a02952fe42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('afa2e701598d20110228.csv')  # Replace with correct file name if different

# %%
df.head()
# Out:
#     id;date;NH4;BSK5;Suspended;O2;NO3;NO2;SO4;PO4;CL
# 0  1;17.02.2000;0.33;2.77;12;12.3;9.5;0.057;154;0...
# 1  1;11.05.2000;0.044;3;51.6;14.61;17.75;0.034;35...
# 2  1;11.09.2000;0.032;2.1;24.5;9.87;13.8;0.173;41...
# 3  1;13.12.2000;0.17;2.23;35.6;12.4;17.13;0.099;2...
# 4  1;02.03.2001;0;3.03;48.8;14.69;10;0.065;281.6;...
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_12.groupby('id;date;NH4;BSK5;Suspended;O2;NO3;NO2;SO4;PO4;CL').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2861 entries, 0 to 2860
# Data columns (total 1 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   id;date;NH4;BSK5;Suspended;O2;NO3;NO2;SO4;PO4;CL  2861 non-null   object
# dtypes: object(1)
# memory usage: 22.5+ KB

# %%
df.shape
# Out:
# (2861, 1)

# %%
df.describe().T
# Out:
#                                                  count unique  \
# id;date;NH4;BSK5;Suspended;O2;NO3;NO2;SO4;PO4;CL  2861   2861
#
#                                                                                                 top  \
# id;date;NH4;BSK5;Suspended;O2;NO3;NO2;SO4;PO4;CL  22;10.02.2021;0;1.78;0;14.3;6.3;0.033;134.4;0....
#
#                                                  freq
# id;date;NH4;BSK5;Suspended;O2;NO3;NO2;SO4;PO4;CL    1

# %%
df.isnull().sum()
# Out:
# id;date;NH4;BSK5;Suspended;O2;NO3;NO2;SO4;PO4;CL    0
# dtype: int64

# %%
df.head(100)
# Out:
#      id;date;NH4;BSK5;Suspended;O2;NO3;NO2;SO4;PO4;CL
# 0   1;17.02.2000;0.33;2.77;12;12.3;9.5;0.057;154;0...
# 1   1;11.05.2000;0.044;3;51.6;14.61;17.75;0.034;35...
# 2   1;11.09.2000;0.032;2.1;24.5;9.87;13.8;0.173;41...
# 3   1;13.12.2000;0.17;2.23;35.6;12.4;17.13;0.099;2...
# 4   1;02.03.2001;0;3.03;48.8;14.69;10;0.065;281.6;...
# ..                                                ...
# 95  2;19.10.2004;0.016;2.1;10.8;10.61;5.88;0.074;1...
# 96  2;13.01.2005;0;2.09;4.4;13.83;6.24;0.031;112.8...
# 97  2;07.04.2005;0.038;2.46;33.2;12.45;8.88;0.029;...
# 98  2;10.08.2005;0;1.83;18.8;5.75;2.81;0.031;78.1;...
# 99  2;25.10.2005;0.049;1.84;3.6;9.14;4.01;0.038;56...
#
# [100 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['index'].plot(kind='hist', bins=20, title='index')
# ...
